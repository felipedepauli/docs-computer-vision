# %% [markdown]
# # Importing the required libraries

# %%
import os
import glob
from IPython.display import Image, display
from IPython import display

# %%
display.clear_output()

# %%
# !nvidia-smi

# %%
HOME = os.getcwd()
print(HOME)

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ghLVPhdSMsFZL3wLnHPE")
project = rf.workspace("the-unbelievable-factory").project("piupiu")
dataset = project.version(1).download("yolov5")

# %%
# %cd {HOME}
ultralytics.checks()

# %%
# %cd {dataset.location}

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/PiuPiu/data.yaml epochs=70 imgsz=640

# %%
# !ls {HOME}/runs/detct/train/

# %% [markdown]
# # Displaying the Confusion Matrix
#
# Confusion matrix is the chart that show how our model handles differente classes
#
# 80% of the time, the model detect correctly that there is a pothole, while 20% of the time, when the pothole is there but the model is not able to detect it

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=900)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)

# %%
# !ls /content/runs/detect/train_2/results.png

# %%
# Validate Custom Model
# Here, we are taking the model best weights and using them to validate the model.
# Similarly as before we are using CLI to do that. The only difference is our mode = val instead.
# Of train. Validation script is using test dataset that was not used before.
# %cd {HOME}
# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data=/content/datasets/PiuPiu/data.yaml

# %% [markdown]
# # Inference with Custom Model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/01.jpeg

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/02.jpeg

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/03.jpeg

# %%
Image("/content/runs/detect/predict/1.jpg")
